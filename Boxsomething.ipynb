# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as st
import scipy.optimize as opt
from scipy.interpolate import interp1d
import numpy.polynomial.polynomial as poly

x = [57,60,66,72,85,110,124,144,169,200,210,234,344,462,700,800,900,1000,1171,1400] #impedance Z
y = [10,100,500,1000,1500,2000,2500,3000,3500,4000,4500,5000,7000,10000,15000,17500,20000,22500,25000,30000] #frequency f

y_err = np.std(y)
print(type(y_err))

# def xsquare(x,y,y_err):
#     interpol = scipy.interp1d(x,y,kind='linear')
#     xnew = np.linspace(0, 10, num=41, endpoint=True)
#     plt.plot(x,y,'o',xnew,interpol(xnew,))
#     return plt.plot(x,y,'o',xnew,interpol(xnew,))

interpol = interp1d(x,y,kind='linear')
xnew = np.linspace(x[0], x[-1], num=len(x)*10, endpoint=True)

xc = poly.polyfit(x,y,3)
ffit = poly.polyval(xnew,xc)
plt.plot(xnew,ffit)
plt.scatter(x,y)
plt.title('Impedance vs. Frequency')
plt.show
# Out:
# <type 'numpy.float64'>
# <function matplotlib.pyplot.show>
